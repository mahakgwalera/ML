# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv('df1', index_col=0)
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.017755     0.048072    -0.001723     0.002432
# std       0.957223     1.004197     0.982384     1.066366
# min      -3.693201    -2.719020    -2.987971    -3.182746
# 25%      -0.639101    -0.652530    -0.690831    -0.676107
# 50%      -0.017793     0.058035    -0.012805    -0.044868
# 75%       0.623478     0.696946     0.706496     0.721699
# max       3.412236     3.199850     3.342484     2.879793

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   object
#  1   A           1000 non-null   float64
#  2   B           1000 non-null   float64
#  3   C           1000 non-null   float64
#  4   D           1000 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# #### Graph Functions
# 1. plot                  - simple line plot
# 2. plot.area             - filled version of line plot
# 3. plot.bar/ plot.barh   - bar graph
# 4. plot.box              - box plot
# 5. plot.density          - density line(smooth curved)
# 6. plot.hexbin           - hexagon version of scatter with density
# 7. plot.hist             - histogram
# 8. plot.kde              - kernel density estimator (density graph)
# 9. plot.pie              - pie chart of categorical data
# 10. plot.scatter         - scatter graph

# %%
df2.plot(); plt.title('Line Plot');plt.show
df2.plot.area(); plt.title('Area Plot');plt.show
df2.plot.bar(); plt.title('Bar Plot');plt.show
df2.plot.box(); plt.title('Box Plot');plt.show
df2.plot.barh(); plt.title('Bar Horizontal Plot');plt.show
df2.plot.density(); plt.title('Density Plot');plt.show
df2.plot.kde(); plt.title('KDE Plot');plt.show
df2.plot.hist(); plt.title('Histogram Plot');plt.show


df2.plot.scatter(x='a', y='b'); plt.title('Scatter Plot');plt.show()


df2.plot_hexbin(x='a', y='b', C='c', gridsize=6);
plt.title('hexbin Plot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP\OneDrive\Desktop\ML\day 18_pandas_graphs.ipynb Cell 7 in <cell line: 14>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> df2.plot.hist(); plt.title('Histogram Plot');plt.show
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> df2.plot.scatter(x='a', y='b'); plt.title('Scatter Plot');plt.show()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> df2.plot_hexbin(x='a', y='b', C='c', gridsize=6);
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a> plt.title('hexbin Plot')
#
# ...

# %%
plt.subplot(4,3,1);df2.plot(); plt.title('Line Plot');plt.show
plt.subplot(4,3,1);df2.plot.area(); plt.title('Area Plot');plt.show
plt.subplot(4,3,1);df2.plot.bar(); plt.title('Bar Plot');plt.show
plt.subplot(4,3,1);df2.plot.box(); plt.title('Box Plot');plt.show
plt.subplot(4,3,1);df2.plot.barh(); plt.title('Bar Horizontal Plot');plt.show
plt.subplot(4,3,1);df2.plot.density(); plt.title('Density Plot');plt.show
plt.subplot(4,3,1);df2.plot.kde(); plt.title('KDE Plot');plt.show
plt.subplot(4,3,1);df2.plot.hist(); plt.title('Histogram Plot');plt.show


plt.subplot(4,3,1);df2.plot.scatter(x='a', y='b'); plt.title('Scatter Plot');plt.show()


df2.plot_Hexbin(x='a', y='b', C='c', gridsize=6);
plt.title('Hexbin Plot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP\OneDrive\Desktop\ML\day 18_pandas_graphs.ipynb Cell 8 in <cell line: 14>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> plt.subplot(4,3,1);df2.plot.hist(); plt.title('Histogram Plot');plt.show
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> plt.subplot(4,3,1);df2.plot.scatter(x='a', y='b'); plt.title('Scatter Plot');plt.show()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/ML/day%2018_pandas_graphs.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> df2.plot_Hexbin(x='a', y='b', C='c', gridsize=6);
# ...

# %%
df1.plot.scatter(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df4 = pd.DataFrame({'gift':[40,60,80,20],'name':['mahak','hii','hello','hiiiiiii']})
df4.head()
# Out:
#    gift      name
# 0    40     mahak
# 1    60       hii
# 2    80     hello
# 3    20  hiiiiiii

# %%
plt.figure(figsize=(5,5))
df4['gift'].plot.pie(autopct='%d%%', labels = df4['name'])
# Out:
# <AxesSubplot:ylabel='gift'>

# %% [markdown]
# seaborn

# %%
import seaborn as sns

# %% [markdown]
# ###### categories
# 1. categorical plots
#     a. countplot (hue can be used | comparison)
#     b. barplot (one value is categorical(x) and one is numerical(y))
#     c. boxplot
#     d. violinplot
#     e. swarmplot
# 2. distribution plots
#     a. distplot
#     b. displot
#     c. joinplot
#     d. pairplot
#     e. kdeplot
#     f. rugplot
#     g. scatterplot
# 3. matrix plots
#     a. heatmap
#     b. clustermap
#     c. pairplot (same as above)
# 4. regression plots
#     a. lmplot
#     b.regplot
# 5. grid plots
#     a.pairgrid
#     b. jointgrid
#     c.facetgrid

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.groupby(['sex', 'time'])['day'].value_counts().sort_index()
# Out:
# sex     time
# Male    Lunch   Thur    30
#                 Fri      3
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     0
#                 Fri      7
#                 Sat     59
#                 Sun     58
# Female  Lunch   Thur    31
#                 Fri      4
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     1
#                 Fri      5
#                 Sat     28
#                 Sun     18
# Name: day, dtype: int64

# %%
sns.countplot(x='day', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x='day', y='total_bill', data= tips, estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data= tips, hue='time', estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data= tips, hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data= tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data= tips, hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data= tips, hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data= tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data= tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
